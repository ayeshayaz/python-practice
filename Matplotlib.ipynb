# %% [markdown]
# <a href="https://colab.research.google.com/github/ayeshayaz/python-practice/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy matplotlib

# %%
import numpy as np
import matplotlib.pylab as plt

# %%
x = np.linspace(0, 1, 100)
y = x ** 2
plt.plot(x, y);

# %%
x = np.linspace(0, 1, 20)
y = x ** 2
plt.scatter(x, y);

# %%
x = np.linspace(0, 1, 100)
y = x ** 2
plt.hist(y, bins=30);

# %%
x = np.linspace(0, 1, 100)
for i in [1, 2, 3]:
    y = x ** i
    plt.plot(x, y, label=f"power={i}")
plt.legend();

# %%
x, y = np.random.normal(0, 1, (2, 1000))
plt.scatter(x, y, s=10, alpha=0.5, color='pink')
x, y = np.random.normal(2, 0.5, (2, 1000))
plt.scatter(x, y, s=10, alpha=0.5, color='purple');

# %%
x1 = np.random.normal(0, 1, (1000))
x2 = np.random.normal(2, 1, (1000))
plt.hist(x1, alpha=0.5, color="purple", bins=30)
plt.hist(x2, alpha=0.2, color="orange", bins=30);

# %%
x = np.linspace(0, 1.5, 100)
for i, style in [(1, ':'), (2, '-.'), (3, '--')]:
    y = x ** i
    plt.plot(x, y, label=f"power={i}", linestyle=style, color='gray', linewidth=1)
plt.legend();

# %%
plt.figure(figsize=(10, 3))

x = np.linspace(0, 1.5, 100)
for i, style in [(1, ':'), (2, '-.'), (3, '--')]:
    y = x ** i
    plt.plot(x, y, label=f"power={i}", linestyle=style, color='gray', linewidth=1)

plt.legend()
plt.title("Powers of x")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.xlim(0.1, 1.4)
plt.ylim(None, 2.5);

# %%
plt.figure(figsize=(7,7))
for i, mu in enumerate([0, 1, 2]):
    for j, sigma in enumerate([0.1, 0.2, 0.3]):
        x = np.random.normal(mu, sigma, (1000,))
        plt.subplot(3, 3, 3 * i + j + 1)
        plt.hist(x)
        plt.xlim(-1, 4)

# %%
def grid_plots(mus, sigmas):
    plt.figure(figsize=(7,7))
    for i, mu in enumerate(mus):
        for j, sigma in enumerate(sigmas):
            x = np.random.normal(mu, sigma, (1000,))
            plt.subplot(len(mus), len(sigmas), len(sigmas) * i + j + 1)
            plt.hist(x, bins=30)
            plt.title(f"$\mu$={mu}, $\sigma$={sigma}")
            plt.xlim(min(mus) - max(sigmas)*3, max(mus) + max(sigmas)*3)

grid_plots(mus=[0.1, 0.3, 0.5], sigmas=[0.1, 0.4])
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_499/2490776661.py:8: SyntaxWarning: invalid escape sequence '\m'
#   plt.title(f"$\mu$={mu}, $\sigma$={sigma}")
# /tmp/ipykernel_499/2490776661.py:8: SyntaxWarning: invalid escape sequence '\s'
#   plt.title(f"$\mu$={mu}, $\sigma$={sigma}")

# %%
def grid_plots(n, m):
  fig, axes = plt.subplots(n, m, figsize=(7, 7), sharex=True, sharey=True)
  for i, ax in enumerate(axes.flat):
      x = np.random.normal(i, 1, (1000,))
      ax.hist(x, bins=30)
      ax.set_title(f"$\mu$={i}, $\sigma$={1}")

grid_plots(3, 3)
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_499/3897912147.py:6: SyntaxWarning: invalid escape sequence '\m'
#   ax.set_title(f"$\mu$={i}, $\sigma$={1}")
# /tmp/ipykernel_499/3897912147.py:6: SyntaxWarning: invalid escape sequence '\s'
#   ax.set_title(f"$\mu$={i}, $\sigma$={1}")
